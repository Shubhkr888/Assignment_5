# %%
# Question 1

{}

# %%
# Question 2
dict = {'foo' : 42}
type(dict)
# Out:
# dict

# %% [markdown]
# Question 3
#
# The items stored in a dictionary are unordered, while the items in a list are ordered.

# %% [markdown]
# Question 4
#
# Error

# %%
#Question 5,6

spam = {'a': 1, 'b':2, 'c':3}

print(spam.keys())
print(spam.values())
print(spam.items())
# Out:
# dict_keys(['a', 'b', 'c'])
# dict_values([1, 2, 3])
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
#Question 7

dictn = {'Car':'Swift', 'model': 'SUV'}
print(dictn)
dictn['colour'] = 'black'
print(dictn)
dictn.setdefault('colour','black')
print(dictn)
# Out:
# {'Car': 'Swift', 'model': 'SUV'}
# {'Car': 'Swift', 'model': 'SUV', 'colour': 'black'}
# {'Car': 'Swift', 'model': 'SUV', 'colour': 'black'}

# %% [markdown]
# #Question 8
# import pprint
# dictn = {'Car':'Swift', 'model': 'SUV'}
# pprint.print(dictn)
